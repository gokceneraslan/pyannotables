# %%
from pathlib import Path
import os
import tempfile
import urllib.request

import pandas as pd
import numpy as np
import pyranges as pr

from tqdm.auto import tqdm

# %%
def fetch_genes_and_transcripts(release=99, 
                                species='homo_sapiens',
                                build='GRCh38',
                                pub_build='',
                                release2=None,
                                datadir=Path('pyannotables') / Path('data'),
                                join_gdf=None):

    if release2 is None:
        release2 = release

    gtf_url = f'http://ftp.ensembl.org/pub/{pub_build.lower()}/release-{release}/gtf/{species}/{species.capitalize()}.{build}.{release2}.chr_patch_hapl_scaff.gtf.gz'

    with tempfile.TemporaryDirectory() as tmpdir:
        full_path = Path(tmpdir) / 'file.gtf.gz'
        urllib.request.urlretrieve(gtf_url, full_path)
        df = pr.read_gtf(full_path, output_df=True)
    
    gdf = df[df.Feature == 'gene'][['Chromosome', 'Source', 'Start', 'End', 'Strand',
                                    'gene_id', 'gene_name', 'gene_source',
                                    'gene_biotype']].drop_duplicates().set_index('gene_id')
    if join_gdf is not None:
        gdf = gdf.join(join_gdf)

    tdf = df[df.Feature == 'transcript'][['Chromosome', 'Start', 'End', 'Strand',
                                          'gene_id', 'transcript_id']].drop_duplicates().set_index('transcript_id')
    datadir.mkdir(exist_ok=True)
    gdf.to_pickle(datadir / f'datafile_{species}-{build}-ensembl{release}.pkl.xz')
    tdf.to_pickle(datadir / f'datafile_{species}-{build}-ensembl{release}-tx2gene.pkl.xz')
    
    return gdf, tdf

# %% [markdown]
# ## Human annotations

# %% [markdown]
# ### Download HGNC gene name table

# %%
url = 'https://www.genenames.org/cgi-bin/download/custom?col=gd_app_sym&col=gd_app_name&col=gd_status&col=gd_prev_sym&col=gd_aliases&col=gd_pub_chrom_map&col=gd_pub_ensembl_id&status=Approved&status=Entry%20Withdrawn&hgnc_dbtag=on&order_by=gd_app_sym_sort&format=text&submit=submit'
human_genes = pd.read_table(url)
human_genes = human_genes[~human_genes['Ensembl gene ID'].isnull()].set_index('Ensembl gene ID')
human_genes.rename(columns={'Chromosome': 'Chromosome_region'}, inplace=True)
human_genes
# Out:
#                 Approved symbol  \
# Ensembl gene ID
# ENSG00000121410            A1BG
# ENSG00000268895        A1BG-AS1
# ENSG00000148584            A1CF
# ENSG00000175899             A2M
# ENSG00000245105         A2M-AS1
# ...                         ...
# ENSG00000162378          ZYG11B
# ENSG00000159840             ZYX
# ENSG00000274572           ZYXP1
# ENSG00000074755           ZZEF1
# ENSG00000036549            ZZZ3
#
#                                                      Approved name    Status  \
# Ensembl gene ID
# ENSG00000121410                             alpha-1-B glycoprotein  Approved
# ENSG00000268895                               A1BG antisense RNA 1  Approved
# ENSG00000148584                     APOBEC1 complementation factor  Approved
# ENSG00000175899                              alpha-2-macroglobulin  Approved
# ENSG00000245105                                A2M antisense RNA 1  Approved
# ...                                                            ...       ...
# ENSG00000162378       zyg-11 family member B, cell cycle regulator  Approved
# ENSG00000159840                                              zyxin  Approved
# ENSG00000274572                                 zyxin pseudogene 1  Approved
# ENSG00000074755  zinc finger ZZ-type and EF-hand domain contain...  Approved
# ENSG00000036549                   zinc finger ZZ-type containing 3  Approved
#
#                             Previous symbols  \
# Ensembl gene ID
# ENSG00000121410                          NaN
# ENSG00000268895  NCRNA00181, A1BGAS, A1BG-AS
# ENSG00000148584                          NaN
# ENSG00000175899                          NaN
# ENSG00000245105                          NaN
# ...                                      ...
# ENSG00000162378                        ZYG11
# ENSG00000159840                          NaN
# ENSG00000274572                          NaN
# ENSG00000074755                          NaN
# ENSG00000036549                          NaN
#
#                                      Alias symbols Chromosome_region
# Ensembl gene ID
# ENSG00000121410                                NaN          19q13.43
# ENSG00000268895                           FLJ23569          19q13.43
# ENSG00000148584  ACF, ASP, ACF64, ACF65, APOBEC1CF          10q11.23
# ENSG00000175899             FWP007, S863-7, CPAMD5          12p13.31
# ENSG00000245105                                NaN          12p13.31
# ...                                            ...               ...
# ENSG00000162378                           FLJ13456            1p32.3
# ENSG00000159840                                NaN              7q34
# ENSG00000274572                                NaN           8q24.23
# ENSG00000074755           KIAA0399, ZZZ4, FLJ10821           17p13.2
# ENSG00000036549                DKFZP564I052, ATAC1            1p31.1
#
# [36941 rows x 6 columns]

# %% [markdown]
# ### GRCh38

# %%
species = 'homo_sapiens'

for release in tqdm((84, 93, 99)):
    gdf, tdf = fetch_genes_and_transcripts(release, species, join_gdf=human_genes)
    
    display(gdf.head())
    display(tdf.head())
# Out:
# HBox(children=(IntProgress(value=0, max=3), HTML(value='')))
#                 Chromosome   Source  Start    End Strand     gene_name  \
# gene_id
# ENSG00000223972          1   havana  11869  14409      +       DDX11L1
# ENSG00000227232          1   havana  14404  29570      -        WASH7P
# ENSG00000278267          1  ensembl  17369  17436      -     MIR6859-1
# ENSG00000243485          1   havana  29554  31109      +  RP11-34P13.3
# ENSG00000274890          1  ensembl  30366  30503      +     MIR1302-2
#
#                 gene_source                        gene_biotype  \
# gene_id
# ENSG00000223972      havana  transcribed_unprocessed_pseudogene
# ENSG00000227232      havana              unprocessed_pseudogene
# ENSG00000278267     ensembl                               miRNA
# ENSG00000243485      havana                             lincRNA
# ENSG00000274890     ensembl                               miRNA
#
#                 Approved symbol                      Approved name    Status  \
# gene_id
# ENSG00000223972         DDX11L1      DEAD/H-box helicase 11 like 1  Approved
# ENSG00000227232          WASH7P  WASP family homolog 7, pseudogene  Approved
# ENSG00000278267             NaN                                NaN       NaN
# ENSG00000243485     MIR1302-2HG                MIR1302-2 host gene  Approved
# ENSG00000274890             NaN                                NaN       NaN
#
#                 Previous symbols Alias symbols Chromosome_region
# gene_id
# ENSG00000223972              NaN           NaN           1p36.33
# ENSG00000227232              NaN        FAM39F           1p36.33
# ENSG00000278267              NaN           NaN               NaN
# ENSG00000243485              NaN           NaN           1p36.33
# ENSG00000274890              NaN           NaN               NaN
#                 Chromosome  Start    End Strand          gene_id
# transcript_id
# ENST00000456328          1  11869  14409      +  ENSG00000223972
# ENST00000450305          1  12010  13670      +  ENSG00000223972
# ENST00000488147          1  14404  29570      -  ENSG00000227232
# ENST00000619216          1  17369  17436      -  ENSG00000278267
# ENST00000473358          1  29554  31097      +  ENSG00000243485
#                 Chromosome   Source  Start    End Strand    gene_name  \
# gene_id
# ENSG00000223972          1   havana  11869  14409      +      DDX11L1
# ENSG00000227232          1   havana  14404  29570      -       WASH7P
# ENSG00000278267          1  mirbase  17369  17436      -    MIR6859-1
# ENSG00000243485          1   havana  29554  31109      +  MIR1302-2HG
# ENSG00000284332          1  mirbase  30366  30503      +    MIR1302-2
#
#                 gene_source                        gene_biotype  \
# gene_id
# ENSG00000223972      havana  transcribed_unprocessed_pseudogene
# ENSG00000227232      havana              unprocessed_pseudogene
# ENSG00000278267     mirbase                               miRNA
# ENSG00000243485      havana                             lincRNA
# ENSG00000284332     mirbase                               miRNA
#
#                 Approved symbol                      Approved name    Status  \
# gene_id
# ENSG00000223972         DDX11L1      DEAD/H-box helicase 11 like 1  Approved
# ENSG00000227232          WASH7P  WASP family homolog 7, pseudogene  Approved
# ENSG00000278267             NaN                                NaN       NaN
# ENSG00000243485     MIR1302-2HG                MIR1302-2 host gene  Approved
# ENSG00000284332       MIR1302-2                    microRNA 1302-2  Approved
#
#                 Previous symbols   Alias symbols Chromosome_region
# gene_id
# ENSG00000223972              NaN             NaN           1p36.33
# ENSG00000227232              NaN          FAM39F           1p36.33
# ENSG00000278267              NaN             NaN               NaN
# ENSG00000243485              NaN             NaN           1p36.33
# ENSG00000284332       MIRN1302-2  hsa-mir-1302-2           1p36.33
#                 Chromosome  Start    End Strand          gene_id
# transcript_id
# ENST00000456328          1  11869  14409      +  ENSG00000223972
# ENST00000450305          1  12010  13670      +  ENSG00000223972
# ENST00000488147          1  14404  29570      -  ENSG00000227232
# ENST00000619216          1  17369  17436      -  ENSG00000278267
# ENST00000473358          1  29554  31097      +  ENSG00000243485
#                 Chromosome   Source  Start    End Strand    gene_name  \
# gene_id
# ENSG00000223972          1   havana  11869  14409      +      DDX11L1
# ENSG00000227232          1   havana  14404  29570      -       WASH7P
# ENSG00000278267          1  mirbase  17369  17436      -    MIR6859-1
# ENSG00000243485          1   havana  29554  31109      +  MIR1302-2HG
# ENSG00000284332          1  mirbase  30366  30503      +    MIR1302-2
#
#                 gene_source                        gene_biotype  \
# gene_id
# ENSG00000223972      havana  transcribed_unprocessed_pseudogene
# ENSG00000227232      havana              unprocessed_pseudogene
# ENSG00000278267     mirbase                               miRNA
# ENSG00000243485      havana                              lncRNA
# ENSG00000284332     mirbase                               miRNA
#
#                 Approved symbol                      Approved name    Status  \
# gene_id
# ENSG00000223972         DDX11L1      DEAD/H-box helicase 11 like 1  Approved
# ENSG00000227232          WASH7P  WASP family homolog 7, pseudogene  Approved
# ENSG00000278267             NaN                                NaN       NaN
# ENSG00000243485     MIR1302-2HG                MIR1302-2 host gene  Approved
# ENSG00000284332       MIR1302-2                    microRNA 1302-2  Approved
#
#                 Previous symbols   Alias symbols Chromosome_region
# gene_id
# ENSG00000223972              NaN             NaN           1p36.33
# ENSG00000227232              NaN          FAM39F           1p36.33
# ENSG00000278267              NaN             NaN               NaN
# ENSG00000243485              NaN             NaN           1p36.33
# ENSG00000284332       MIRN1302-2  hsa-mir-1302-2           1p36.33
#                 Chromosome  Start    End Strand          gene_id
# transcript_id
# ENST00000456328          1  11869  14409      +  ENSG00000223972
# ENST00000450305          1  12010  13670      +  ENSG00000223972
# ENST00000488147          1  14404  29570      -  ENSG00000227232
# ENST00000619216          1  17369  17436      -  ENSG00000278267
# ENST00000473358          1  29554  31097      +  ENSG00000243485

# %% [markdown]
# ### GRCh37

# %%
release = 99
release2 = 87

gdf, tdf = fetch_genes_and_transcripts(release, species, build='GRCh37', pub_build='GRCh37', release2=release2, join_gdf=human_genes)

# %%
gdf.head()
# Out:
#                 Chromosome          Source  Start    End Strand   gene_name  \
# gene_id
# ENSG00000223972          1  ensembl_havana  11869  14412      +     DDX11L1
# ENSG00000227232          1  ensembl_havana  14363  29806      -      WASH7P
# ENSG00000243485          1  ensembl_havana  29554  31109      +  MIR1302-10
# ENSG00000237613          1  ensembl_havana  34554  36081      -     FAM138A
# ENSG00000268020          1  ensembl_havana  52473  54936      +      OR4G4P
#
#                     gene_source gene_biotype Approved symbol  \
# gene_id
# ENSG00000223972  ensembl_havana   pseudogene         DDX11L1
# ENSG00000227232  ensembl_havana   pseudogene          WASH7P
# ENSG00000243485  ensembl_havana      lincRNA     MIR1302-2HG
# ENSG00000237613  ensembl_havana      lincRNA         FAM138A
# ENSG00000268020  ensembl_havana   pseudogene          OR4G4P
#
#                                                      Approved name    Status  \
# gene_id
# ENSG00000223972                      DEAD/H-box helicase 11 like 1  Approved
# ENSG00000227232                  WASP family homolog 7, pseudogene  Approved
# ENSG00000243485                                MIR1302-2 host gene  Approved
# ENSG00000237613       family with sequence similarity 138 member A  Approved
# ENSG00000268020  olfactory receptor family 4 subfamily G member...  Approved
#
#                 Previous symbols Alias symbols Chromosome_region
# gene_id
# ENSG00000223972              NaN           NaN           1p36.33
# ENSG00000227232              NaN        FAM39F           1p36.33
# ENSG00000243485              NaN           NaN           1p36.33
# ENSG00000237613              NaN          F379           1p36.33
# ENSG00000268020              NaN           NaN           1p36.33

# %% [markdown]
# ## Mouse annotations

# %% [markdown]
# ### GRCm38

# %%
gdf, tdf = fetch_genes_and_transcripts(99, 'mus_musculus', build='GRCm38')

# %%
gdf.head()
# Out:
#                    Chromosome          Source    Start      End Strand  \
# gene_id
# ENSMUSG00000102693          1          havana  3073253  3074322      +
# ENSMUSG00000064842          1         ensembl  3102016  3102125      +
# ENSMUSG00000051951          1  ensembl_havana  3205901  3671498      -
# ENSMUSG00000102851          1          havana  3252757  3253236      +
# ENSMUSG00000103377          1          havana  3365731  3368549      -
#
#                         gene_name     gene_source          gene_biotype
# gene_id
# ENSMUSG00000102693  4933401J01Rik          havana                   TEC
# ENSMUSG00000064842        Gm26206         ensembl                 snRNA
# ENSMUSG00000051951           Xkr4  ensembl_havana        protein_coding
# ENSMUSG00000102851        Gm18956          havana  processed_pseudogene
# ENSMUSG00000103377        Gm37180          havana                   TEC

# %%
tdf.head()
# Out:
#                    Chromosome    Start      End Strand             gene_id
# transcript_id
# ENSMUST00000193812          1  3073253  3074322      +  ENSMUSG00000102693
# ENSMUST00000082908          1  3102016  3102125      +  ENSMUSG00000064842
# ENSMUST00000162897          1  3205901  3216344      -  ENSMUSG00000051951
# ENSMUST00000159265          1  3206523  3215632      -  ENSMUSG00000051951
# ENSMUST00000070533          1  3214482  3671498      -  ENSMUSG00000051951
